# %% [markdown]
# # Домашнее задание

# %% [markdown]
# ## Теория вероятностей

# %% [markdown]
# **Задача 1**. (11 баллов)
#
# В известном магазине техники представлено очень много экземпляров различной бытовой техники двух видов: с возможностью подключения к системе "Умный дом" и без такой возможности. Причем, известно, что эти два вида техники представлены в пропорции 1 : 3 соответственно. Случайным образом выбрали 7 экземпляров техники для розыгрыша среди участниц конкурса "Мисс Рукоделье - 2024".  Какова вероятность, что среди них не более двух экземпляров с возможностью подключения к системе "Умный дом"?
#
# Подробно распишите решение и обоснуйте выбор распределения для моделирования сюжета задачи. Ответ округлите до трёх знаков.

# %% [markdown]
# Решение:
# Соглласно условиям задачи у нас есть 7 эксперементов, каждый из которых может иметь одно из  двух исходов - быть подключенным к системе умный дом или нет. Вероятность которых в каждом случае одинакова. Под такие условия нам подходит биноминальное распределение. Вероятность того, что техника будет с подключением у нас по условию задачи 1\3, т.е. каждая четвертая техника, (т.е. вероятность = 0.25)

# %%
import numpy as np
import scipy as sp
import scipy.stats as st

# %%
p = 0.25 # вероятность успеха в одном испытании # q = 0.75 # вероятность отсутствия подключения
n = 7 # кол-во эксперементов
k = 2 # кол-во успехов 
result = sp.stats.binom.cdf(k, n, p) #

print(round(result,3))
# Out:
# 0.756

# %% [markdown]
# **Задача 2** (30 баллов)
#
# Дан закон распределения количества публикаций в которой группе телеграм-каналов:

# %% [markdown]
# $$
# \begin{array}{|c|c|c|c|c|c|c|}
# \hline X \text { (число публикаций) } & 0 & 1 & 2 & 3 & 4 & 5 \\
# \hline \mathrm{P} \text { (вероятность) } & ? & 0,3 & 0,3 & 0,2 & 0,1 & 0,1 \\
# \hline
# \end{array}
# $$

# %% [markdown]
# Найдите пропущенную вероятность для X = 0, математическое ожидание и дисперсию. Решите задачу "вручную" и с помощью python.

# %% [raw]
# Решение.
# Для того чтобы найти вероятность = 0, воспользуемся тем знание, что сумма всех вероятностей = 1. Тогда: Р=1-0,1-0,1-0,2-0,3-0,3=0 Итог Вероятность 0=0.
# Расчитаем мат ожидание (среднее значение). Формула для расчета: M(X) = Σ [xᵢ * P(X = xᵢ)]  М(х)=(0 * 0) + (1 * 0.3) + (2 * 0.3) + (3 * 0.2) + (4 * 0.1) + (5 * 0.1) Итог=2.4.
# Расчет дисперсии: D(х) = M(х**2) - (M(х))**2. М(х) мы уже нашли = 2.4. Теперь найдем М(х**2).
# М(х)**2=(0**2 * 0) + (1**2 * 0.3) + (2**2 * 0.3) + (3**2 * 0.2) + (4**2 * 0.1) + (5**2 * 0.1)=  0 + 0.3 + 1.2 + 1.8 + 1.6 + 2.5= 7.4. Тогда дисперсия D(х)= 7.4-(2.4)**2= 1.64

# %%
x = np.array ([0, 1, 2, 3, 4, 5]) #число публикаций
p = ([0, 0.3, 0.3, 0.2, 0.1, 0.1]) #вероятность

M_x = np.sum(x*p) #мат ожидание
D_x = np.sum((x**2) * p) - M_x**2 #дисперсия

print("Математическое ожидание:", M_x)
print("Дисперсия:", D_x)
# Out:
# Математическое ожидание: 2.4
# Дисперсия: 1.6400000000000006

# %% [markdown]
# **Задача 3** (25 баллов)

# %% [markdown]
# Компания приобрела 10 000 новых ноутбуков. Вероятность поломки одного ноутбука в течение месяца равна 0,0002. Предполагается, что поломки отдельных ноутбуков происходят независимо друг от друга.
#
# **Вопрос 1**. Найдите вероятность того, что за месяц сломается ровно 1 ноутбук.
# Решение объясните. (5 баллов)

# %% [markdown]
# **Вопрос 2**. Компания планирует ввести программу расширенной гарантии, по которой она будет бесплатно ремонтировать или заменять ноутбуки, сломавшиеся в течение месяца. Если общее количество поломок за месяц превысит 5 ноутбуков, компания понесет значительные дополнительные расходы.
#
# а) Найдите вероятность того, что за месяц сломается более 5 ноутбуков.Решение объясните (10 баллов)
#
# б) Если стоимость ремонта или замены одного ноутбука составляет 500 долларов, вычислите математическое ожидание общих расходов компании на поломки за один месяц. (10 баллов)

# %% [raw]
# задача 1.
# n = 10 000 (количество ноутбуков)
# p = 0,0002 (вероятность поломки одного ноутбука)
# А = n * p = 10 000 * 0,0002 = 2 - Расчет среднего числа поломок(мат. ожидание)
# Так как у нас минимальное число поломок мы можем воспользоватся формулой распределения Пуассона.
# P(k) = (А^k * e^-А) / k! где: P(k) — вероятность k событий, А — среднее число событий, e — основание натурального логарифма (примерно 2,71828).
# k! — факториал числа k (k! = 1 * 2 * 3 * ... * k).
# Нам надо найти вероятность поломки ровно 1 ноутбука (k = 1):
# P(1) = (2^1 * e^-2) / 1! = (2 * 0,1353) / 1 = 0,2707

# %%
A = 2 #вероятность поломки одного ноутбука
k = 1 #ожидаемое колличество поломок  

# Вычисление вероятности:
result = st.poisson.pmf(k, A) #pmf ставим ддля нахождения по пуасону

print(f"Вероятность P(k={k}) = {result}")
# Out:
# Вероятность P(k=1) = 0.2706705664732254

# %% [raw]
# задача 2
# Тут тоже воспользуемся распределением Пуассона (частный случай биноминального распределения), как и в первом вопросе. Количество ноутбуков большое (n = 10 000), малая вероятность поломки одного ноутбука  (p = 0,0002). А = n * p = 10 000 * 0,0002 = 2 - Расчет среднего числа поломок( мат. ожидание). Решим с помощью Python.
# Наш ответ= 0.016563608480614445 (мы использовали кумулятивную функцию cdf распределения Пуассона для того, чтобы постчитать вероятность того, что количество поломок будет не больше 5, а затем мы вычли это значение из 1, чтобы получить вероятность того, что количество поломок будет больше 5.)

# %%
A = 2 #вероятность поломки одного ноутбука
k = 5 #ожидаемое колличество поломок  

# Вычисление вероятности:
result = st.poisson.cdf(k, A) #cdf вычислит нам  P(k ≤ 5):
P_k=1-result
print(f"Вероятность поломки менее или равно {k} ноутбуков - P(k<={k}) = {P_k}")
print(f"Вероятность поломки более {k} ноутбуков - P(k={k}) = {P_k}")
# Out:
# Вероятность поломки менее или равно 5 ноутбуков - P(k<=5) = 0.016563608480614445
# Вероятность поломки более 5 ноутбуков - P(k=5) = 0.016563608480614445

# %% [raw]
# Математическое ожидание (среднее значение) количества поломок (А) мы уже нашлли выше = 2. Т.е. для нахождены расходов S=500(условие задачи)*A=1000

# %%
pay=500
S = pay * A
print(f"Ожидаемые расходы на ремонт в месяц: {S}")
# Out:
# Ожидаемые расходы на ремонт в месяц: 1000
